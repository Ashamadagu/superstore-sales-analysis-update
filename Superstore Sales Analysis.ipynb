# %%
import pandas as pd

# %%
df = pd.read_csv('superstore_data.csv')
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# min       0.000000     0.000000     0.000000         0.000000
# 25%      24.000000    23.750000     1.000000        16.000000
# 50%      49.000000   173.500000     8.000000        67.000000
# 75%      74.000000   504.250000    33.000000       232.000000
# max      99.000000  1493.000000   199.000000      1725.000000
#
#        MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# count      2240.000000       2240.000000   2240.000000        2240.000000
# mean         37.525446         27.062946     44.021875           2.325000
# std          54.628979         41.280498     52.167439           1.932238
# min           0.000000          0.000000      0.000000           0.000000
# 25%           3.000000          1.000000      9.000000           1.000000
# 50%          12.000000          8.000000     24.000000           2.000000
# 75%          50.000000         33.000000     56.000000           3.000000
# max         259.000000        263.000000    362.000000          15.000000
#
#        NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# count      2240.000000          2240.000000        2240.000000
# mean          4.084821             2.662054           5.790179
# std           2.778714             2.923101           3.250958
# min           0.000000             0.000000           0.000000
# 25%           2.000000             0.000000           3.000000
# 50%           4.000000             2.000000           5.000000
# 75%           6.000000             4.000000           8.000000
# max          27.000000            28.000000          13.000000
#
#        NumWebVisitsMonth     Response     Complain
# count        2240.000000  2240.000000  2240.000000
# mean            5.316518     0.149107     0.009375
# std             2.426645     0.356274     0.096391
# min             0.000000     0.000000     0.000000
# 25%             3.000000     0.000000     0.000000
# 50%             6.000000     0.000000     0.000000
# 75%             7.000000     0.000000     0.000000
# max            20.000000     1.000000     1.000000

# %%
list(df.columns)
# Out:
# ['Id',
#  'Year_Birth',
#  'Education',
#  'Marital_Status',
#  'Income',
#  'Kidhome',
#  'Teenhome',
#  'Dt_Customer',
#  'Recency',
#  'MntWines',
#  'MntFruits',
#  'MntMeatProducts',
#  'MntFishProducts',
#  'MntSweetProducts',
#  'MntGoldProds',
#  'NumDealsPurchases',
#  'NumWebPurchases',
#  'NumCatalogPurchases',
#  'NumStorePurchases',
#  'NumWebVisitsMonth',
#  'Response',
#  'Complain']

# %%
print("1. What product sold most and why we think it sold most ")
products_df = df.loc[:, ['MntWines',
 'MntFruits',
 'MntMeatProducts',
 'MntFishProducts',
 'MntSweetProducts',
 'MntGoldProds']]

products_df.head()
# Out:
# 1. What product sold most and why we think it sold most
#    MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# 0       189        104              379              111               189
# 1       464          5               64                7                 0
# 2       134         11               59               15                 2
# 3        10          0                1                0                 0
# 4         6         16               24               11                 0
#
#    MntGoldProds
# 0           218
# 1            37
# 2            30
# 3             0
# 4            34

# %%
products_df.dropna()
products_df = products_df.astype(float)
products_df.head()
# Out:
#    MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# 0     189.0      104.0            379.0            111.0             189.0
# 1     464.0        5.0             64.0              7.0               0.0
# 2     134.0       11.0             59.0             15.0               2.0
# 3      10.0        0.0              1.0              0.0               0.0
# 4       6.0       16.0             24.0             11.0               0.0
#
#    MntGoldProds
# 0         218.0
# 1          37.0
# 2          30.0
# 3           0.0
# 4          34.0

# %%
products_df.describe()
# Out:
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2240.000000  2240.000000      2240.000000      2240.000000
# mean    303.935714    26.302232       166.950000        37.525446
# std     336.597393    39.773434       225.715373        54.628979
# min       0.000000     0.000000         0.000000         0.000000
# 25%      23.750000     1.000000        16.000000         3.000000
# 50%     173.500000     8.000000        67.000000        12.000000
# 75%     504.250000    33.000000       232.000000        50.000000
# max    1493.000000   199.000000      1725.000000       259.000000
#
#        MntSweetProducts  MntGoldProds
# count       2240.000000   2240.000000
# mean          27.062946     44.021875
# std           41.280498     52.167439
# min            0.000000      0.000000
# 25%            1.000000      9.000000
# 50%            8.000000     24.000000
# 75%           33.000000     56.000000
# max          263.000000    362.000000

# %%
products_df = products_df.apply(pd.to_numeric)

# %%
product_sold_most = products_df.sum().idxmax()
print(product_sold_most + " = product that sold the most")
# Out:
# MntWines = product that sold the most

# %%
print("2. How much was earned from the product that sold most ")
amount_earned = products_df['MntFruits'].sum()
print("Amount earned from the most sold product is {0}".format(amount_earned))
# Out:
# 2. How much was earned from the product that sold most
# Amount earned from the most sold product is 58917.0

# %%
print("3. What time should we display advertisements to maximize buying of products ")
df
# Out:
# 3. What time should we display advertisements to maximize buying of products
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# 1            0   6/15/2014        0       464  ...                7
# 2            1   5/13/2014        0       134  ...               15
# 3            1   11/5/2014        0        10  ...                0
# 4            0    8/4/2014        0         6  ...               11
# ...        ...         ...      ...       ...  ...              ...
# 2235         1    7/3/2013       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0   3/12/2012       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    1/9/2012       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 0                  189           218                  1                4
# 1                    0            37                  1                7
# 2                    2            30                  1                3
# 3                    0             0                  1                1
# 4                    0            34                  2                3
# ...                ...           ...                ...              ...
# 2235                48            78                  2                5
# 2236                 8            16                  1                1
# 2237                 5            14                  2                6
# 2238               165            63                  1                5
# 2239                 0           144                  1                8
#
#       NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  Response  \
# 0                       4                  6                  1         1
# 1                       3                  7                  5         1
# 2                       2                  5                  2         0
# 3                       0                  2                  7         0
# 4                       1                  2                  7         1
# ...                   ...                ...                ...       ...
# 2235                    2                 11                  4         0
# 2236                    0                  3                  8         0
# 2237                    1                  5                  8         0
# 2238                    4                 10                  3         0
# 2239                    5                  4                  7         1
#
#       Complain
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2235         0
# 2236         0
# 2237         0
# 2238         0
# 2239         0
#
# [2240 rows x 22 columns]

# %%
purchase_df = df.loc[:, ['NumDealsPurchases',
 'NumWebPurchases',
 'NumCatalogPurchases',
 'NumStorePurchases']]
purchase_df
# Out:
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0                     1                4                    4
# 1                     1                7                    3
# 2                     1                3                    2
# 3                     1                1                    0
# 4                     2                3                    1
# ...                 ...              ...                  ...
# 2235                  2                5                    2
# 2236                  1                1                    0
# 2237                  2                6                    1
# 2238                  1                5                    4
# 2239                  1                8                    5
#
#       NumStorePurchases
# 0                     6
# 1                     7
# 2                     5
# 3                     2
# 4                     2
# ...                 ...
# 2235                 11
# 2236                  3
# 2237                  5
# 2238                 10
# 2239                  4
#
# [2240 rows x 4 columns]

# %%
purchase_df.describe()
# Out:
#        NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count        2240.000000      2240.000000          2240.000000
# mean            2.325000         4.084821             2.662054
# std             1.932238         2.778714             2.923101
# min             0.000000         0.000000             0.000000
# 25%             1.000000         2.000000             0.000000
# 50%             2.000000         4.000000             2.000000
# 75%             3.000000         6.000000             4.000000
# max            15.000000        27.000000            28.000000
#
#        NumStorePurchases
# count        2240.000000
# mean            5.790179
# std             3.250958
# min             0.000000
# 25%             3.000000
# 50%             5.000000
# 75%             8.000000
# max            13.000000

# %%
sum_ = purchase_df.sum(axis = 1)
sum_
# Out:
# 0       15
# 1       18
# 2       11
# 3        4
# 4        8
#         ..
# 2235    20
# 2236     5
# 2237    14
# 2238    20
# 2239    18
# Length: 2240, dtype: int64

# %%
purchase_df['total_purchase'] = sum_
purchase_df
# Out:
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0                     1                4                    4
# 1                     1                7                    3
# 2                     1                3                    2
# 3                     1                1                    0
# 4                     2                3                    1
# ...                 ...              ...                  ...
# 2235                  2                5                    2
# 2236                  1                1                    0
# 2237                  2                6                    1
# 2238                  1                5                    4
# 2239                  1                8                    5
#
#       NumStorePurchases  total_purchase
# 0                     6              15
# 1                     7              18
# 2                     5              11
# 3                     2               4
# 4                     2               8
# ...                 ...             ...
# 2235                 11              20
# 2236                  3               5
# 2237                  5              14
# 2238                 10              20
# 2239                  4              18
#
# [2240 rows x 5 columns]

# %%
formated_date = pd.to_datetime(df['Dt_Customer']).astype('datetime64[ns]')
formated_date
# Out:
# 0      2014-06-16
# 1      2014-06-15
# 2      2014-05-13
# 3      2014-11-05
# 4      2014-08-04
#           ...
# 2235   2013-07-03
# 2236   2013-01-22
# 2237   2012-03-12
# 2238   2012-11-29
# 2239   2012-01-09
# Name: Dt_Customer, Length: 2240, dtype: datetime64[ns]

# %%
# formated_date = formated_date.dt.day
# formated_date

# %%
purchase_df['formated_date'] = formated_date
purchase_df
# Out:
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0                     1                4                    4
# 1                     1                7                    3
# 2                     1                3                    2
# 3                     1                1                    0
# 4                     2                3                    1
# ...                 ...              ...                  ...
# 2235                  2                5                    2
# 2236                  1                1                    0
# 2237                  2                6                    1
# 2238                  1                5                    4
# 2239                  1                8                    5
#
#       NumStorePurchases  total_purchase formated_date
# 0                     6              15    2014-06-16
# 1                     7              18    2014-06-15
# 2                     5              11    2014-05-13
# 3                     2               4    2014-11-05
# 4                     2               8    2014-08-04
# ...                 ...             ...           ...
# 2235                 11              20    2013-07-03
# 2236                  3               5    2013-01-22
# 2237                  5              14    2012-03-12
# 2238                 10              20    2012-11-29
# 2239                  4              18    2012-01-09
#
# [2240 rows x 6 columns]

# %%
total_g_date = purchase_df.loc[:, ['formated_date',
 'total_purchase']]
total_g_date
# Out:
#      formated_date  total_purchase
# 0       2014-06-16              15
# 1       2014-06-15              18
# 2       2014-05-13              11
# 3       2014-11-05               4
# 4       2014-08-04               8
# ...            ...             ...
# 2235    2013-07-03              20
# 2236    2013-01-22               5
# 2237    2012-03-12              14
# 2238    2012-11-29              20
# 2239    2012-01-09              18
#
# [2240 rows x 2 columns]

# %%
total_date_grouped = total_g_date.groupby('formated_date')
totals = total_date_grouped.sum()
totals
# Out:
#                total_purchase
# formated_date
# 2012-01-08                 63
# 2012-01-09                 18
# 2012-01-10                108
# 2012-01-11                 23
# 2012-01-12                 74
# ...                       ...
# 2014-12-02                 55
# 2014-12-03                 77
# 2014-12-04                 14
# 2014-12-05                167
# 2014-12-06                  4
#
# [663 rows x 1 columns]

# %%
df_totals = pd.DataFrame(totals)
df_totals.iloc[:, 0]
# Out:
# formated_date
# 2012-01-08     63
# 2012-01-09     18
# 2012-01-10    108
# 2012-01-11     23
# 2012-01-12     74
#              ...
# 2014-12-02     55
# 2014-12-03     77
# 2014-12-04     14
# 2014-12-05    167
# 2014-12-06      4
# Name: total_purchase, Length: 663, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(df_totals.iloc[:, 0])
  
plt.xlabel('Date')
plt.ylabel('Max Purchase')
plt.title('Purchase Arranged By Date')
plt.show()

# %%
maxValues = totals.loc[totals['total_purchase'].idxmax()]
maxValues
# Out:
# total_purchase    213
# Name: 2012-08-31 00:00:00, dtype: int64

# %%
data = totals.rename(columns={'x': 'y'})
data = data.sort_index()
data.head()
# Out:
#                total_purchase
# formated_date
# 2012-01-08                 63
# 2012-01-09                 18
# 2012-01-10                108
# 2012-01-11                 23
# 2012-01-12                 74

# %%
print(f'Number of rows with missing values: {data.isnull().any(axis=1).mean()}')
# Out:
# Number of rows with missing values: 0.0

# %%
steps = 36
data_train = data[:-steps]
data_test  = data[-steps:]

# %%
print(f"Train dates : {data_train.index.min()} --- {data_train.index.max()}  (n={len(data_train)})")
print(f"Test dates  : {data_test.index.min()} --- {data_test.index.max()}  (n={len(data_test)})")
# Out:
# Train dates : 2012-01-08 00:00:00 --- 2014-06-28 00:00:00  (n=627)
# Test dates  : 2014-06-29 00:00:00 --- 2014-12-06 00:00:00  (n=36)

# %%
data_test['total_purchase']
# Out:
# formated_date
# 2014-06-29     26
# 2014-07-01     49
# 2014-07-02     64
# 2014-07-03     27
# 2014-07-04     72
# 2014-07-05     66
# 2014-07-06     38
# 2014-08-02      4
# 2014-08-03     43
# 2014-08-04     28
# 2014-08-05     40
# 2014-08-06     35
# 2014-09-01     22
# 2014-09-02     18
# 2014-09-03     43
# 2014-09-04     46
# 2014-09-05      6
# 2014-09-06     31
# 2014-10-01     49
# 2014-10-02     62
# 2014-10-03     72
# 2014-10-04      6
# 2014-10-05     45
# 2014-10-06     49
# 2014-11-01     80
# 2014-11-02     35
# 2014-11-03     19
# 2014-11-04     45
# 2014-11-05     65
# 2014-11-06     10
# 2014-12-01     21
# 2014-12-02     55
# 2014-12-03     77
# 2014-12-04     14
# 2014-12-05    167
# 2014-12-06      4
# Name: total_purchase, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(9, 4))
data_train['total_purchase'].plot(ax=ax, label='train')
data_test['total_purchase'].plot(ax=ax, label='test')
ax.legend();

# %%
print("4. Which product has the highest tax amount and freight charges")
# Out:
# 4. Which product has the highest tax amount and freight charges

# %%
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# 1            0   6/15/2014        0       464  ...                7
# 2            1   5/13/2014        0       134  ...               15
# 3            1   11/5/2014        0        10  ...                0
# 4            0    8/4/2014        0         6  ...               11
# ...        ...         ...      ...       ...  ...              ...
# 2235         1    7/3/2013       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0   3/12/2012       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    1/9/2012       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 0                  189           218                  1                4
# 1                    0            37                  1                7
# 2                    2            30                  1                3
# 3                    0             0                  1                1
# 4                    0            34                  2                3
# ...                ...           ...                ...              ...
# 2235                48            78                  2                5
# 2236                 8            16                  1                1
# 2237                 5            14                  2                6
# 2238               165            63                  1                5
# 2239                 0           144                  1                8
#
#       NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  Response  \
# 0                       4                  6                  1         1
# 1                       3                  7                  5         1
# 2                       2                  5                  2         0
# 3                       0                  2                  7         0
# 4                       1                  2                  7         1
# ...                   ...                ...                ...       ...
# 2235                    2                 11                  4         0
# 2236                    0                  3                  8         0
# 2237                    1                  5                  8         0
# 2238                    4                 10                  3         0
# 2239                    5                  4                  7         1
#
#       Complain
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2235         0
# 2236         0
# 2237         0
# 2238         0
# 2239         0
#
# [2240 rows x 22 columns]

# %%
salesOrder = pd.read_excel('DataSet_SalesOrders.xlsx')
salesOrder
# Out:
#       SalesOrderID  OrderDate  ProdID  CustID  TerritoryID  Quantity  \
# 0             2679 2016-12-28    7022      12            1        40
# 1             2680 2016-12-28    7031      26            4        20
# 2             2681 2016-12-28    7122      19            2        45
# 3             2682 2016-12-29    6022      47            3        30
# 4             2683 2016-12-29    5021      31            3        30
# ...            ...        ...     ...     ...          ...       ...
# 1163          3842 2017-12-29    7122      16            5        20
# 1164          3843 2017-12-29    7123      17            5        15
# 1165          3844 2017-12-29    7123      67            2        10
# 1166          3845 2017-12-29    7123      16            5        15
# 1167          3846 2017-12-29    7123      42            5        50
#
#       UnitPrice  SubTotal     TaxAmt  Freight    TotalDue CredApr  ShipID  \
# 0           895     35800   2685.000   57.280   38542.280     ADB   64883
# 1          3363     67260   5044.500   72.960   72377.460     ADB   64881
# 2          2785    125325   9399.375  112.832  134837.207     ADB   64884
# 3          1699     50970   3822.750   58.400   54851.150     ADB   64882
# 4          2479     74370   5577.750   92.000   80039.750     ADB   64885
# ...         ...       ...        ...      ...         ...     ...     ...
# 1163       2785     55700   4177.500   54.592   59932.092     ADB   66035
# 1164       4888     73320   5499.000   50.000   78869.000      AB   66039
# 1165       4888     48880   3666.000   36.000   52582.000     ADB   66048
# 1166       4888     73320   5499.000   50.000   78869.000      AB   66037
# 1167       4888    244400  18330.000  148.000  262878.000     ADB   66036
#
#       InvoiceID ModifiedDate     ModifiedTime
# 0        100635   2017-01-02  17:26:18.778000
# 1        100633   2016-12-31  17:45:36.022000
# 2        100636   2017-01-03  13:38:19.662000
# 3        100634   2017-01-02  14:51:20.210000
# 4        100637   2017-01-03  08:23:55.395000
# ...         ...          ...              ...
# 1163     101797   2018-01-02  15:10:26.847000
# 1164     101793   2018-01-02  08:27:01.877000
# 1165     101787   2018-01-02  18:05:21.571000
# 1166     101796   2018-01-02  07:40:33.355000
# 1167     101791   2018-01-02  08:45:49.597000
#
# [1168 rows x 16 columns]

# %%
salesOrder.dropna()
# Out:
#       SalesOrderID  OrderDate  ProdID  CustID  TerritoryID  Quantity  \
# 0             2679 2016-12-28    7022      12            1        40
# 1             2680 2016-12-28    7031      26            4        20
# 2             2681 2016-12-28    7122      19            2        45
# 3             2682 2016-12-29    6022      47            3        30
# 4             2683 2016-12-29    5021      31            3        30
# ...            ...        ...     ...     ...          ...       ...
# 1163          3842 2017-12-29    7122      16            5        20
# 1164          3843 2017-12-29    7123      17            5        15
# 1165          3844 2017-12-29    7123      67            2        10
# 1166          3845 2017-12-29    7123      16            5        15
# 1167          3846 2017-12-29    7123      42            5        50
#
#       UnitPrice  SubTotal     TaxAmt  Freight    TotalDue CredApr  ShipID  \
# 0           895     35800   2685.000   57.280   38542.280     ADB   64883
# 1          3363     67260   5044.500   72.960   72377.460     ADB   64881
# 2          2785    125325   9399.375  112.832  134837.207     ADB   64884
# 3          1699     50970   3822.750   58.400   54851.150     ADB   64882
# 4          2479     74370   5577.750   92.000   80039.750     ADB   64885
# ...         ...       ...        ...      ...         ...     ...     ...
# 1163       2785     55700   4177.500   54.592   59932.092     ADB   66035
# 1164       4888     73320   5499.000   50.000   78869.000      AB   66039
# 1165       4888     48880   3666.000   36.000   52582.000     ADB   66048
# 1166       4888     73320   5499.000   50.000   78869.000      AB   66037
# 1167       4888    244400  18330.000  148.000  262878.000     ADB   66036
#
#       InvoiceID ModifiedDate     ModifiedTime
# 0        100635   2017-01-02  17:26:18.778000
# 1        100633   2016-12-31  17:45:36.022000
# 2        100636   2017-01-03  13:38:19.662000
# 3        100634   2017-01-02  14:51:20.210000
# 4        100637   2017-01-03  08:23:55.395000
# ...         ...          ...              ...
# 1163     101797   2018-01-02  15:10:26.847000
# 1164     101793   2018-01-02  08:27:01.877000
# 1165     101787   2018-01-02  18:05:21.571000
# 1166     101796   2018-01-02  07:40:33.355000
# 1167     101791   2018-01-02  08:45:49.597000
#
# [1168 rows x 16 columns]

# %%
highestTaxAmount = salesOrder.loc[salesOrder['TaxAmt'].idxmax()]
highestTaxAmount
# Out:
# SalesOrderID                   2712
# OrderDate       2017-01-10 00:00:00
# ProdID                         7123
# CustID                           58
# TerritoryID                       2
# Quantity                         50
# UnitPrice                      4888
# SubTotal                     244400
# TaxAmt                      18330.0
# Freight                       148.0
# TotalDue                   262878.0
# CredApr                         ADB
# ShipID                        64916
# InvoiceID                    100665
# ModifiedDate    2017-01-13 00:00:00
# ModifiedTime        17:08:57.091000
# Name: 33, dtype: object

# %%
highestForeignCharges = salesOrder.loc[salesOrder['Freight'].idxmax()]
highestForeignCharges
# Out:
# SalesOrderID                   2987
# OrderDate       2017-04-14 00:00:00
# ProdID                         7031
# CustID                           19
# TerritoryID                       2
# Quantity                         50
# UnitPrice                      3363
# SubTotal                     168150
# TaxAmt                     12611.25
# Freight                       170.4
# TotalDue                  180931.65
# CredApr                         ADB
# ShipID                        65192
# InvoiceID                    100944
# ModifiedDate    2017-04-17 00:00:00
# ModifiedTime        18:05:13.940000
# Name: 308, dtype: object

# %%
list(salesOrder.columns)
# Out:
# ['SalesOrderID',
#  'OrderDate',
#  'ProdID',
#  'CustID',
#  'TerritoryID',
#  'Quantity',
#  'UnitPrice',
#  'SubTotal',
#  'TaxAmt',
#  'Freight',
#  'TotalDue',
#  'CredApr',
#  'ShipID',
#  'InvoiceID',
#  'ModifiedDate',
#  'ModifiedTime']

# %%
list(df.columns)
# Out:
# ['Id',
#  'Year_Birth',
#  'Education',
#  'Marital_Status',
#  'Income',
#  'Kidhome',
#  'Teenhome',
#  'Dt_Customer',
#  'Recency',
#  'MntWines',
#  'MntFruits',
#  'MntMeatProducts',
#  'MntFishProducts',
#  'MntSweetProducts',
#  'MntGoldProds',
#  'NumDealsPurchases',
#  'NumWebPurchases',
#  'NumCatalogPurchases',
#  'NumStorePurchases',
#  'NumWebVisitsMonth',
#  'Response',
#  'Complain']

# %%
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
salesOrder.head()
# Out:
#    SalesOrderID  OrderDate  ProdID  CustID  TerritoryID  Quantity  UnitPrice  \
# 0          2679 2016-12-28    7022      12            1        40        895
# 1          2680 2016-12-28    7031      26            4        20       3363
# 2          2681 2016-12-28    7122      19            2        45       2785
# 3          2682 2016-12-29    6022      47            3        30       1699
# 4          2683 2016-12-29    5021      31            3        30       2479
#
#    SubTotal    TaxAmt  Freight    TotalDue CredApr  ShipID  InvoiceID  \
# 0     35800  2685.000   57.280   38542.280     ADB   64883     100635
# 1     67260  5044.500   72.960   72377.460     ADB   64881     100633
# 2    125325  9399.375  112.832  134837.207     ADB   64884     100636
# 3     50970  3822.750   58.400   54851.150     ADB   64882     100634
# 4     74370  5577.750   92.000   80039.750     ADB   64885     100637
#
#   ModifiedDate     ModifiedTime
# 0   2017-01-02  17:26:18.778000
# 1   2016-12-31  17:45:36.022000
# 2   2017-01-03  13:38:19.662000
# 3   2017-01-02  14:51:20.210000
# 4   2017-01-03  08:23:55.395000

# %%
order = df.loc[:, ['Id','MntWines',
 'MntFruits',
 'MntMeatProducts',
 'MntFishProducts',
 'MntSweetProducts',
 'MntGoldProds']]
order
# Out:
#          Id  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0      1826       189        104              379              111
# 1         1       464          5               64                7
# 2     10476       134         11               59               15
# 3      1386        10          0                1                0
# 4      5371         6         16               24               11
# ...     ...       ...        ...              ...              ...
# 2235  10142       372         18              126               47
# 2236   5263         5         10               13                3
# 2237     22       185          2               88               15
# 2238    528       267         38              701              149
# 2239   4070       169         24              553              188
#
#       MntSweetProducts  MntGoldProds
# 0                  189           218
# 1                    0            37
# 2                    2            30
# 3                    0             0
# 4                    0            34
# ...                ...           ...
# 2235                48            78
# 2236                 8            16
# 2237                 5            14
# 2238               165            63
# 2239                 0           144
#
# [2240 rows x 7 columns]

# %%
orders = 1*(order.set_index('Id') > 0)
orders
# Out:
#        MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# Id
# 1826          1          1                1                1
# 1             1          1                1                1
# 10476         1          1                1                1
# 1386          1          0                1                0
# 5371          1          1                1                1
# ...         ...        ...              ...              ...
# 10142         1          1                1                1
# 5263          1          1                1                1
# 22            1          1                1                1
# 528           1          1                1                1
# 4070          1          1                1                1
#
#        MntSweetProducts  MntGoldProds
# Id
# 1826                  1             1
# 1                     0             1
# 10476                 1             1
# 1386                  0             0
# 5371                  0             1
# ...                 ...           ...
# 10142                 1             1
# 5263                  1             1
# 22                    1             1
# 528                   1             1
# 4070                  0             1
#
# [2240 rows x 6 columns]

# %%
import numpy as np
order_count_relation = pd.DataFrame(data = orders.values.T@orders.values, columns = orders.columns, index = orders.columns)
order_count_relation
# Out:
#                   MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# MntWines              2227       1832             2227             1843
# MntFruits             1832       1840             1840             1648
# MntMeatProducts       2227       1840             2239             1855
# MntFishProducts       1843       1648             1855             1856
# MntSweetProducts      1809       1622             1820             1642
# MntGoldProds          2166       1804             2178             1817
#
#                   MntSweetProducts  MntGoldProds
# MntWines                      1809          2166
# MntFruits                     1622          1804
# MntMeatProducts               1820          2178
# MntFishProducts               1642          1817
# MntSweetProducts              1821          1787
# MntGoldProds                  1787          2179

# %%
correlations = order_count_relation.corr()
correlations
# Out:
#                   MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# MntWines          1.000000   0.678623         0.999764         0.690935
# MntFruits         0.678623   1.000000         0.674122         0.233782
# MntMeatProducts   0.999764   0.674122         1.000000         0.694423
# MntFishProducts   0.690935   0.233782         0.694423         1.000000
# MntSweetProducts  0.623812   0.075223         0.625423         0.193422
# MntGoldProds      0.992673   0.663642         0.993985         0.681103
#
#                   MntSweetProducts  MntGoldProds
# MntWines                  0.623812      0.992673
# MntFruits                 0.075223      0.663642
# MntMeatProducts           0.625423      0.993985
# MntFishProducts           0.193422      0.681103
# MntSweetProducts          1.000000      0.621335
# MntGoldProds              0.621335      1.000000

# %%
print("From the above df, MintWines and MintMeatProducts have a joint value of 0.999764 which is greater than all other values")
print("This indicates that the two are the products that are mostly sold together")
# Out:
# From the above df, MintWines and MintMeatProducts have a joint value of 0.999764 which is greater than all other values
# This indicates that the two are the products that are mostly sold together

# %%
import seaborn as sns
sns.scatterplot(x="MntWines", y="MntMeatProducts", data=correlations);
